# %% [markdown]
# <a href="https://colab.research.google.com/github/anselmo-pitombeira/Notebooks/blob/master/GridWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Feb  7 17:06:31 2023

@author: Anselmo_
"""

import numpy as np


def computa_valor_politica(S,r,prob_local,gama,pi,eps=0.01):
    
    """
    S: Conjunto de estados (lista de duplas)
    r: Recompensa (valor neagativo recebido em cada passo do agente)
    prob_local: Probabilidade do agente ir realmente para o local escolhido (valor em [0,1])
    gama: Fator de desconto no intervalo (0,1]
    pi: Política de decisão (dicionário indexado pelos estados)
    
    Retorna: Dicionário com valor de cada estado
    """

    valor_politica = {}
    
    ##Inicializa o valor da politica como zero
    for (i,j) in S:
        valor_politica[(i,j)] = 0
    
    ##print("Valor da politica = ", valor_politica)
    
    ##Iteracao de valor (para computar o valor da politica)
    
    
    for k in range(10000):
        
        maior_diferenca = 0
        
        novo_valor_politica = {}    ##Guarda novos valores
    
        for (i,j) in S:
            
            ##Testa se o estado é terminal (Nunca atualiza o estado terminal)
            if (i,j) == estado_terminal:
                continue
            
            ##Identifica a ação associada ao estado
            acao = pi[(i,j)]
            
            soma = 0    ##Variável auxiliar para computar o valor esperado dos próximos estados
            
            if acao == "direita":
                
                ##Local À direita
                if (i,j+1) in S:
            
                    soma += prob_local*valor_politica[(i,j+1)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*valor_politica[(i,j)]
                ##Local à esquerda
                if (i,j-1) in S:
                    
                    soma += (1-prob_local)/3*valor_politica[(i,j-1)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                
                ##Local acima
                if (i-1,j) in S:
                    
                    soma += (1-prob_local)/3*valor_politica[(i-1,j)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                
                ##Local abaixo
                if (i+1,j) in S:
                    
                    soma += (1-prob_local)/3*valor_politica[(i+1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                    
            if acao == "esquerda":
                
                ##Local À direita
                if (i,j+1) in S:
            
                    soma += (1-prob_local)/3*valor_politica[(i,j+1)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                ##Local à esquerda
                if (i,j-1) in S:
                    
                    soma += prob_local*valor_politica[(i,j-1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*valor_politica[(i,j)]
                
                ##Local acima
                if (i-1,j) in S:
                    
                    soma += (1-prob_local)/3*valor_politica[(i-1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                
                ##Local abaixo
                if (i+1,j) in S:
                    
                    soma += (1-prob_local)/3*valor_politica[(i+1,j)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                    
            if acao == "baixo":
                 
                 ##Local À direita
                if (i,j+1) in S:
             
                     soma += (1-prob_local)/3*valor_politica[(i,j+1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                 ##Local à esquerda
                if (i,j-1) in S:
                     
                     soma += (1-prob_local)/3*valor_politica[(i,j-1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                 
                 ##Local acima
                if (i-1,j) in S:
                     
                     soma += (1-prob_local)/3*valor_politica[(i-1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                 
                 ##Local abaixo
                if (i+1,j) in S:
                     
                     soma += prob_local*valor_politica[(i+1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*valor_politica[(i,j)]
            
            
            if acao == "cima":
                 
                 ##Local À direita
                if (i,j+1) in S:
             
                     soma += (1-prob_local)/3*valor_politica[(i,j+1)]
                     
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                    
                 ##Local à esquerda
                if (i,j-1) in S:
                     
                     soma += (1-prob_local)/3*valor_politica[(i,j-1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
                 
                 ##Local acima
                if (i-1,j) in S:
                     
                     soma += prob_local*valor_politica[(i-1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*valor_politica[(i,j)]
                 
                 ##Local abaixo
                if (i+1,j) in S:
                     
                    soma += (1-prob_local)/3*valor_politica[(i+1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*valor_politica[(i,j)]
            
            ##Atualiza valor do estado
            novo_valor_politica[(i,j)] = r+gama*soma
            
            ##Computa  diferença entre novo valor e valor anterior
            
            diferenca = np.abs(novo_valor_politica[(i,j)] - valor_politica[(i,j)])
            
            if  diferenca > maior_diferenca:
                
                maior_diferenca = diferenca
                
        ##Atualiza valor da politica
        novo_valor_politica[estado_terminal] = 0    ##valor do estado terminal é sempre zero
        valor_politica = novo_valor_politica
        print("\nIteração ", k)
        print("Valor maior diferenca = ", maior_diferenca)
        
        ##Se a diferença for menor que a tolerancia, quebre o loop
        if maior_diferenca < eps:
            break
        
    return valor_politica


def computa_funcao_valor_otima(S,A,r,prob_local,gama,eps=0.01):
    
    """
    Computa a função de valor ótima para um GridWorld.
    
    S: Conjunto de estados (lista de duplas)
    A: Conjunto de acoes possiveis
    r: Recompensa (valor neagativo recebido em cada passo do agente)
    prob_local: Probabilidade do agente ir realmente para o local escolhido (valor em [0,1])
    gama: Fator de desconto no intervalo (0,1]
    
    Retorna: Dicionário com aproximação do valor ótimo de cada estado
    """

    funcao_valor = {}
    
    ##Inicializa o valor de cada estado como zero
    for (i,j) in S:
        funcao_valor[(i,j)] = 0
    
    ##Iteracao de valor (para computar a função de valor ótima)
    
    for k in range(10000):
        
        maior_diferenca = 0
        
        nova_funcao_valor = {}    ##Guarda novos valores
    
        for (i,j) in S:
            
            ##Testa se o estado é terminal (Nunca atualiza o estado terminal)
            if (i,j) == estado_terminal:
                continue
            
            ##Loop ações (implementação do operador max) 
            ##Computa o lado direito da equacao de Bellman
            ##para cada ação e identifica aquela com maior valor
            
            maior_valor = -np.inf    ## -infinito
            
            for acao in A:
            
                soma = 0    ##Variável auxiliar para computar o valor esperado dos próximos estados
                
                if acao == "direita":
                    
                    ##Local À direita
                    if (i,j+1) in S:
                
                        soma += prob_local*funcao_valor[(i,j+1)]
                        
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += prob_local*funcao_valor[(i,j)]
                    ##Local à esquerda
                    if (i,j-1) in S:
                        
                        soma += (1-prob_local)/3*funcao_valor[(i,j-1)]
                        
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                    
                    ##Local acima
                    if (i-1,j) in S:
                        
                        soma += (1-prob_local)/3*funcao_valor[(i-1,j)]
                        
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                    
                    ##Local abaixo
                    if (i+1,j) in S:
                        
                        soma += (1-prob_local)/3*funcao_valor[(i+1,j)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                        
                if acao == "esquerda":
                    
                    ##Local À direita
                    if (i,j+1) in S:
                
                        soma += (1-prob_local)/3*funcao_valor[(i,j+1)]
                        
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                    ##Local à esquerda
                    if (i,j-1) in S:
                        
                        soma += prob_local*funcao_valor[(i,j-1)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += prob_local*funcao_valor[(i,j)]
                    
                    ##Local acima
                    if (i-1,j) in S:
                        
                        soma += (1-prob_local)/3*funcao_valor[(i-1,j)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                    
                    ##Local abaixo
                    if (i+1,j) in S:
                        
                        soma += (1-prob_local)/3*funcao_valor[(i+1,j)]
                        
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                        
                if acao == "baixo":
                     
                     ##Local À direita
                    if (i,j+1) in S:
                 
                         soma += (1-prob_local)/3*funcao_valor[(i,j+1)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                     ##Local à esquerda
                    if (i,j-1) in S:
                         
                         soma += (1-prob_local)/3*funcao_valor[(i,j-1)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                     
                     ##Local acima
                    if (i-1,j) in S:
                         
                         soma += (1-prob_local)/3*funcao_valor[(i-1,j)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                     
                     ##Local abaixo
                    if (i+1,j) in S:
                         
                         soma += prob_local*funcao_valor[(i+1,j)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += prob_local*funcao_valor[(i,j)]
                
                
                if acao == "cima":
                     
                     ##Local À direita
                    if (i,j+1) in S:
                 
                         soma += (1-prob_local)/3*funcao_valor[(i,j+1)]
                         
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                        
                     ##Local à esquerda
                    if (i,j-1) in S:
                         
                         soma += (1-prob_local)/3*funcao_valor[(i,j-1)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                     
                     ##Local acima
                    if (i-1,j) in S:
                         
                         soma += prob_local*funcao_valor[(i-1,j)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += prob_local*funcao_valor[(i,j)]
                     
                     ##Local abaixo
                    if (i+1,j) in S:
                         
                        soma += (1-prob_local)/3*funcao_valor[(i+1,j)]
                    else:   ##Local é parede, parmanece no mesmo local
                        soma += (1-prob_local)/3*funcao_valor[(i,j)]
                
                ##Valor associado ao estado (i,j) e ação:
                valor_acao = r+gama*soma
                
                ##Verifica se ação tem valor maior
                
                if valor_acao > maior_valor:                   
                    maior_valor = valor_acao
    
            ##Atualiza valor do estado (identificado pela ação que maximiza o lado direto da Eq. de Bellman)
            nova_funcao_valor[(i,j)] = maior_valor
            
            ##Computa  diferença entre novo valor e valor anterior
            
            diferenca = np.abs(nova_funcao_valor[(i,j)] - funcao_valor[(i,j)])
            
            if  diferenca > maior_diferenca:
                
                maior_diferenca = diferenca
                
        ##Atualiza valor da politica
        nova_funcao_valor[estado_terminal] = 0    ##valor do estado terminal é sempre zero
        funcao_valor = nova_funcao_valor
        print("\nIteração ", k)
        print("Valor maior diferenca = ", maior_diferenca)
        
        ##Se a diferença for menor que a tolerancia, quebre o loop
        if maior_diferenca < eps:
            break
        
    return funcao_valor

def computa_politica_greedy(S,A,r,prob_local,gama,funcao_valor):
    
    """Computa uma política greedy em relação à função de valor
    S: Conjunto de estados (lista de duplas)
    A: Conjunto de acoes possiveis
    r: Recompensa (valor neagativo recebido em cada passo do agente)
    prob_local: Probabilidade do agente ir realmente para o local escolhido (valor em [0,1])
    gama: Fator de desconto no intervalo (0,1]
    funcao_valor: Uma função de valor na forma de um dicionário cujas chaves são os estados
    """
    
    politica = {}
    
    for (i,j) in S:
        
        ##Testa se o estado é terminal (Nunca atualiza o estado terminal)
        if (i,j) == estado_terminal:
            continue
        
        ##Loop ações (implementação do operador max) 
        ##Computa o lado direito da equacao de Bellman
        ##para cada ação e identifica aquela com maior valor
        
        maior_valor = -np.inf    ## -infinito
        
        for acao in A:
        
            soma = 0    ##Variável auxiliar para computar o valor esperado dos próximos estados
            
            if acao == "direita":
                
                ##Local À direita
                if (i,j+1) in S:
            
                    soma += prob_local*funcao_valor[(i,j+1)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*funcao_valor[(i,j)]
                ##Local à esquerda
                if (i,j-1) in S:
                    
                    soma += (1-prob_local)/3*funcao_valor[(i,j-1)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                
                ##Local acima
                if (i-1,j) in S:
                    
                    soma += (1-prob_local)/3*funcao_valor[(i-1,j)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                
                ##Local abaixo
                if (i+1,j) in S:
                    
                    soma += (1-prob_local)/3*funcao_valor[(i+1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                    
            if acao == "esquerda":
                
                ##Local À direita
                if (i,j+1) in S:
            
                    soma += (1-prob_local)/3*funcao_valor[(i,j+1)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                ##Local à esquerda
                if (i,j-1) in S:
                    
                    soma += prob_local*funcao_valor[(i,j-1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*funcao_valor[(i,j)]
                
                ##Local acima
                if (i-1,j) in S:
                    
                    soma += (1-prob_local)/3*funcao_valor[(i-1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                
                ##Local abaixo
                if (i+1,j) in S:
                    
                    soma += (1-prob_local)/3*funcao_valor[(i+1,j)]
                    
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                    
            if acao == "baixo":
                 
                 ##Local À direita
                if (i,j+1) in S:
             
                     soma += (1-prob_local)/3*funcao_valor[(i,j+1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                 ##Local à esquerda
                if (i,j-1) in S:
                     
                     soma += (1-prob_local)/3*funcao_valor[(i,j-1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                 
                 ##Local acima
                if (i-1,j) in S:
                     
                     soma += (1-prob_local)/3*funcao_valor[(i-1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                 
                 ##Local abaixo
                if (i+1,j) in S:
                     
                     soma += prob_local*funcao_valor[(i+1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*funcao_valor[(i,j)]
            
            
            if acao == "cima":
                 
                 ##Local À direita
                if (i,j+1) in S:
             
                     soma += (1-prob_local)/3*funcao_valor[(i,j+1)]
                     
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                    
                 ##Local à esquerda
                if (i,j-1) in S:
                     
                     soma += (1-prob_local)/3*funcao_valor[(i,j-1)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
                 
                 ##Local acima
                if (i-1,j) in S:
                     
                     soma += prob_local*funcao_valor[(i-1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += prob_local*funcao_valor[(i,j)]
                 
                 ##Local abaixo
                if (i+1,j) in S:
                     
                    soma += (1-prob_local)/3*funcao_valor[(i+1,j)]
                else:   ##Local é parede, parmanece no mesmo local
                    soma += (1-prob_local)/3*funcao_valor[(i,j)]
            
            ##Valor associado ao estado (i,j) e ação:
            valor_acao = r+gama*soma
            
            ##Verifica se ação tem valor maior
            
            if valor_acao > maior_valor:                   
                maior_valor = valor_acao
                politica[(i,j)] = acao
    
    return politica
    


if __name__=="__main__":
    

    ##DEFINIÇÃO DE DADOS DO AMBIENTE
    
    grid_size = 5   ##Tamanho do grid. (grid_size x grid_size)
    gama = 1.0      ##Fator de desconto
    prob_local = 0.9
    parede = [(3,3),(3,4),(3,5),(4,3)]
    r = -1          ##Recompensa em cada acao é -1
    
    ##Conjunto de estados
    S = []
    
    for i in range(1, grid_size+1):
        for j in range(1, grid_size+1):
            
            if (i,j) not in parede:
                S.append((i,j))
                
    estado_terminal = (grid_size, grid_size)        
    print("Conjunto de estados = ", S)
    
    ##Conjunto de ações:
    A = ["baixo", "esquerda", "cima", "direita"]
    
    ##DUAS POLITICAS PARA TESTE:
    
    ##Politica ruim (aleatória)
    pi = {(1,1):"baixo", (1,2):"esquerda", (1,3): "baixo", (1,4):"direita", (1,5):"cima",
          (2,1):"direita" , (2,2):"baixo", (2,3):"esquerda", (2,4):"direita", (2,5):"esquerda",
          (3,1):"cima", (3,2):"direita",
          (4,1):"baixo", (4,2):"esquerda", (4,4):"baixo", (4,5):"esquerda",
          (5,1):"direita", (5,2):"esquerda", (5,3):"cima", (5,4):"direita"}
    
    ##politica boa
    pi2 = {(1,1):"baixo", (1,2):"baixo", (1,3): "esquerda", (1,4):"esquerda", (1,5):"esquerda",
          (2,1):"direita" , (2,2):"baixo", (2,3):"esquerda", (2,4):"esquerda", (2,5):"esquerda",
          (3,1):"baixo", (3,2):"baixo",
          (4,1):"baixo", (4,2):"esquerda", (4,4):"baixo", (4,5):"baixo",
          (5,1):"direita", (5,2):"direita", (5,3):"direita", (5,4):"direita"}
    
    
    ##COMPUTA VALOR DA POLÍTICA
    ##valor_politica = computa_valor_politica(S,r,prob_local,gama,pi2)
    

        
    ##print("\nValor da política = ", valor_politica)
    

    ##Computa função de valor ótima
    f_valor_otima = computa_funcao_valor_otima(S,A,r,prob_local,gama)
    
    print("\nFunção de valor ótima = ", f_valor_otima)
    
    politica_otima = computa_politica_greedy(S,A,r,prob_local,gama,f_valor_otima)
    
    print("\nPolitica otima = ", politica_otima)
# Out:
# Conjunto de estados =  [(1, 1), (1, 2), (1, 3), (1, 4), (1, 5), (2, 1), (2, 2), (2, 3), (2, 4), (2, 5), (3, 1), (3, 2), (4, 1), (4, 2), (4, 4), (4, 5), (5, 1), (5, 2), (5, 3), (5, 4), (5, 5)]
#
# Iteração  0
# Valor maior diferenca =  1.0
#
# Iteração  1
# Valor maior diferenca =  1.0
#
# Iteração  2
# Valor maior diferenca =  1.0
#
# Iteração  3
# Valor maior diferenca =  1.0
#
# Iteração  4
# Valor maior diferenca =  1.0
#
# Iteração  5
# Valor maior diferenca =  1.0
#
# Iteração  6
# Valor maior diferenca =  1.0
#
# Iteração  7
# Valor maior diferenca =  1.0
#
# Iteração  8
# Valor maior diferenca =  1.0
#
# Iteração  9
# Valor maior diferenca =  1.0
#
# Iteração  10
# Valor maior diferenca =  0.6125795110000034
#
# Iteração  11
# Valor maior diferenca =  0.47009486448999915
#
# Iteração  12
# Valor maior diferenca =  0.24803117975799793
#
# Iteração  13
# Valor maior diferenca =  0.15631966237059736
#
# Iteração  14
# Valor maior diferenca =  0.07726188805345302
#
# Iteração  15
# ...
