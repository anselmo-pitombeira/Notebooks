# %% [markdown]
# <a href="https://colab.research.google.com/github/anselmo-pitombeira/Notebooks/blob/master/simulacao_fila.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy.random import default_rng

seed = 42
rng = default_rng(seed)

n = 30            ##Numero de clientes
t = 0             ##Variavel-relogio
tec_medio = 1.3   ##Cliente chegam em media a cada 1.3 min
ta_medio = 1.0    ##Tempo medio de atendimento
q = 0             ##Estado da fila
b = 0             ##Estado do servidor
eventos = []
chegadas = []

for i in range(1, n+1):
    tec = rng.exponential(tec_medio)   ##tec do cliente i
    c = t+tec                         ##Hora de chegada registrada no cronometro
    eventos.append([c, 'chegada'])
    t = c

while len(eventos) > 0:    ##Loop de eventos

    eventos.sort()         ##Ordena eventos crescentemente
    ev = eventos.pop(0)    ##Retira da lista o evento mais cedo
    t = ev[0]              ##Adianta a variavel relogio para o tempo do evento
	
    if ev[1] == 'chegada':
        print("Evento de chegada no tempo t = ",t)
        print("Tamanho da fila = ", q)
        if b == 1:   ##Se servidor ocupado
            q = q+1  ##Incrementa a fila
            
        else:   ##Servidor desocupado
		        b = 1                          ##Servidor fica ocupado
		        ta = rng.exponential(ta_medio)  ##Amostra o tempo de atendimento
		        s = t+ta                       ##Momento de saida do cliente
		        eventos.append([s, 'saida'])   ##Agenda o eventos saida
	
    if ev[1] == 'saida':
        print("Evento de saída no tempo t = ",t)
        print("Tamanho da fila = ", q)
        if q == 0:    ##Fila e zero?	
		        b = 0     ##Servidor desocupa
        else:	
            q = q-1                         ##Decrementa a fila
            ta = rng.exponential(ta_medio)   ##Amostra o tempo de atendimento
            s = t+ta                        ##Computa Momento de saida do cliente
            eventos.append([s, 'saida'])    ##Agenda o eventos saida
# Out:
# Evento de chegada no tempo t =  3.125471185155793
# Tamanho da fila =  0
# Evento de saída no tempo t =  3.5141514213156144
# Tamanho da fila =  0
# Evento de chegada no tempo t =  6.162517737727583
# Tamanho da fila =  0
# Evento de saída no tempo t =  7.42672459529269
# Tamanho da fila =  0
# Evento de chegada no tempo t =  9.262707037564114
# Tamanho da fila =  0
# Evento de chegada no tempo t =  9.626439614371172
# Tamanho da fila =  0
# Evento de chegada no tempo t =  9.738808233979062
# Tamanho da fila =  1
# Evento de saída no tempo t =  9.97119766498024
# Tamanho da fila =  2
# Evento de saída no tempo t =  10.209127619278256
# Tamanho da fila =  1
# Evento de saída no tempo t =  10.670215955535728
# Tamanho da fila =  0
# Evento de chegada no tempo t =  11.62726690439706
# Tamanho da fila =  0
# Evento de saída no tempo t =  12.268823641587574
# Tamanho da fila =  0
# Evento de chegada no tempo t =  13.460215806931904
# Tamanho da fila =  0
# Evento de saída no tempo t =  13.804049168369698
# Tamanho da fila =  0
# Evento de chegada no tempo t =  17.52180055044625
# Tamanho da fila =  0
# Evento de chegada no tempo t =  17.624883006784813
# Tamanho da fila =  0
# Evento de saída no tempo t =  17.843711771352563
# Tamanho da fila =  1
# Evento de saída no tempo t =  18.722626453545107
# Tamanho da fila =  0
# Evento de chegada no tempo t =  18.985412107290927
# Tamanho da fila =  0
# Evento de chegada no tempo t =  19.076979306128077
# Tamanho da fila =  0
# Evento de saída no tempo t =  19.282359316219726
# Tamanho da fila =  1
# Evento de chegada no tempo t =  20.492710022559226
# Tamanho da fila =  0
# Evento de saída no tempo t =  20.61606174125161
# Tamanho da fila =  1
# Evento de saída no tempo t =  22.006925727497517
# Tamanho da fila =  0
# Evento de chegada no tempo t =  22.743435581308177
# Tamanho da fila =  0
# Evento de chegada no tempo t =  23.24639885327506
# Tamanho da fila =  0
# Evento de saída no tempo t =  23.827518509273368
# Tamanho da fila =  1
# Evento de saída no tempo t =  23.900546857253804
# Tamanho da fila =  0
# Evento de chegada no tempo t =  24.847460214735104
# Tamanho da fila =  0
# Evento de chegada no tempo t =  25.0473654447092
# Tamanho da fila =  0
# Evento de chegada no tempo t =  25.16641589231645
# Tamanho da fila =  1
# Evento de chegada no tempo t =  25.57614885508856
# Tamanho da fila =  2
# Evento de saída no tempo t =  25.981527716457858
# Tamanho da fila =  3
# Evento de chegada no tempo t =  26.747707913069767
# Tamanho da fila =  2
# Evento de chegada no tempo t =  27.284588841729803
# Tamanho da fila =  3
# Evento de saída no tempo t =  27.33586570432303
# Tamanho da fila =  4
# Evento de saída no tempo t =  28.457905355780458
# Tamanho da fila =  3
# Evento de saída no tempo t =  28.73795447601688
# Tamanho da fila =  2
# Evento de chegada no tempo t =  28.906190576487514
# Tamanho da fila =  1
# Evento de saída no tempo t =  29.058890667052914
# Tamanho da fila =  2
# Evento de chegada no tempo t =  29.196839860363532
# Tamanho da fila =  1
# Evento de saída no tempo t =  29.224626574354513
# Tamanho da fila =  2
# Evento de saída no tempo t =  29.578990087045973
# Tamanho da fila =  1
# Evento de saída no tempo t =  29.60012984345576
# Tamanho da fila =  0
# Evento de chegada no tempo t =  31.586201203751333
# Tamanho da fila =  0
# Evento de saída no tempo t =  31.753557599867047
# Tamanho da fila =  0
# Evento de chegada no tempo t =  33.18141282592987
# Tamanho da fila =  0
# Evento de chegada no tempo t =  34.03394782608177
# Tamanho da fila =  0
# Evento de saída no tempo t =  34.496469670477026
# Tamanho da fila =  1
# Evento de chegada no tempo t =  34.576160544287134
# Tamanho da fila =  0
# Evento de chegada no tempo t =  35.16547614037488
# Tamanho da fila =  1
# Evento de chegada no tempo t =  35.26567643154723
# Tamanho da fila =  2
# Evento de chegada no tempo t =  35.49919836223415
# Tamanho da fila =  3
# Evento de chegada no tempo t =  36.390114949319674
# Tamanho da fila =  4
# Evento de saída no tempo t =  38.492225941661864
# Tamanho da fila =  5
# Evento de saída no tempo t =  39.0557640340505
# Tamanho da fila =  4
# Evento de saída no tempo t =  39.33980373565132
# Tamanho da fila =  3
# Evento de saída no tempo t =  39.737559989558555
# Tamanho da fila =  2
# Evento de saída no tempo t =  40.09890221249347
# Tamanho da fila =  1
# Evento de saída no tempo t =  40.22853581571707
# Tamanho da fila =  0
