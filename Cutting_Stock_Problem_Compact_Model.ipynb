# %% [markdown]
# <a href="https://colab.research.google.com/github/anselmo-pitombeira/Notebooks/blob/master/Cutting_Stock_Problem_Compact_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install coinor-cbc
#!apt-get install glpk-utils
# !pip install pyomo
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# coinor-cbc is already the newest version (2.10.7+ds1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# Requirement already satisfied: pyomo in /usr/local/lib/python3.12/dist-packages (6.9.5)
# Requirement already satisfied: ply in /usr/local/lib/python3.12/dist-packages (from pyomo) (3.11)

# %%
import pyomo.environ as pyo

# %% [markdown]
# ## Data

# %%
L = 120   #Stock length (cm)
m = 40    #An alternative worst upper bound is sum(demand)

# item types: lengths (cm) and demands (units)
item_lengths = [19, 36, 62, 25, 48]
demand = [10, 12, 15, 31, 17]
n = len(demand)

# %% [markdown]
# ## Model

# %%
# -------- Model --------
model = pyo.ConcreteModel()

# Index Sets
model.I = range(m)
model.J = range(n)

# Parameters
model.L = L
model.l = item_lengths
model.d = demand

# Decision variables
# x[i,j] = number of pieces of type j cut from stock piece i (non-negative integer)
model.x = pyo.Var(model.I, model.J, domain=pyo.NonNegativeIntegers)

# y[i] = 1 if stock piece i is used (cut), 0 otherwise
model.y = pyo.Var(model.I, domain=pyo.Binary)

# Knapsack Constraints
def capacity_rule(model, i):
    # sum_j l_j * x_ij <= L * y_i
    return sum(model.l[j] * model.x[i, j] for j in model.J) <= model.L * model.y[i]
model.knapsack = pyo.Constraint(model.I, rule=capacity_rule)

def demand_rule(model, j):
    # sum_i x_ij >= d_j
    return sum(model.x[i, j] for i in model.I) >= model.d[j]

model.demand = pyo.Constraint(model.J, rule=demand_rule)

# Objective: minimize number of stock pieces used
def obj_rule(model):
    return sum(model.y[i] for i in model.I)

model.obj = pyo.Objective(rule=obj_rule, sense=pyo.minimize)  # default sense=1 (minimize)

# %%
solver = pyo.SolverFactory("cbc")
solver.options["Sec"] = 600 ##Limits execution time in 600 seconds maximum
result = solver.solve(model, tee=True)  # tee=True prints solver output
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.7
# Build Date: Feb 14 2022
#
# command line - /usr/bin/cbc -Sec 600 -printingOptions all -import /tmp/tmp9gj51ek2.pyomo.lp -stat=1 -solve -solu /tmp/tmp9gj51ek2.pyomo.soln (default strategy 1)
# seconds was changed from 1e+100 to 600
# Option for printingOptions changed from normal to all
# Presolve 45 (0) rows, 240 (0) columns and 440 (0) elements
# Statistics for presolved model
# Original problem has 240 integers (40 of which binary)
# ==== 200 zero objective 2 different
# 200 variables have objective of 0
# 40 variables have objective of 1
# ==== absolute objective values 2 different
# 200 variables have objective of 0
# 40 variables have objective of 1
# ==== for integers 200 zero objective 2 different
# 200 variables have objective of 0
# 40 variables have objective of 1
# ==== for integers absolute objective values 2 different
# 200 variables have objective of 0
# 40 variables have objective of 1
# ===== end objective counts
#
#
# Problem has 45 rows, 240 columns (40 with objective) and 440 elements
# There are 40 singletons with objective
# Column breakdown:
# 200 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 40 of type 0.0->1.0
# Row breakdown:
# 0 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 0 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 5 of type G other, 40 of type L 0.0, 0 of type L 1.0,
# 0 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 26.1917 - 0.00 seconds
# Cgl0004I processed model has 45 rows, 240 columns (240 integer (80 of which binary)) and 440 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 31 integers unsatisfied sum - 8.41333
# Cbc0038I Pass   1: suminf.    7.92934 (28) obj. 27 iterations 20
# Cbc0038I Solution found of 27
# Cbc0038I Branch and bound needed to clear up 28 general integers
# Cbc0038I Full problem 45 rows 240 columns, reduced to 31 rows 108 columns
# Cbc0038I Mini branch and bound could not fix general integers
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 195 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.14 seconds)
# Cbc0038I After 0.14 seconds - Feasibility pump exiting - took 0.13 seconds
# Cbc0031I 148 added rows had average density of 37.081081
# Cbc0013I At root node, 148 cuts changed objective from 26.191667 to 26.791718 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 882 row cuts average 4.0 elements, 0 column cuts (118 active)  in 0.100 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6900 row cuts average 50.2 elements, 0 column cuts (0 active)  in 0.356 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 142 row cuts average 4.2 elements, 0 column cuts (0 active)  in 0.066 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 193 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.079 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 2120 row cuts average 7.4 elements, 0 column cuts (0 active)  in 0.060 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 26.791718 (2.25 seconds)
# Cbc0016I Integer solution of 28 found by strong branching after 21533 iterations and 118 nodes (4.98 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 38 rows 132 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 36 rows 121 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 35 rows 109 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 39 rows 129 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 39 rows 124 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 35 rows 94 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 35 rows 90 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 34 rows 90 columns
# Cbc0010I After 1000 nodes, 214 on tree, 28 best solution, best possible 26.791718 (42.05 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 37 rows 95 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 37 rows 100 columns
# Cbc0010I After 2000 nodes, 224 on tree, 28 best solution, best possible 26.791718 (48.00 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 37 rows 97 columns
# Cbc0010I After 3000 nodes, 220 on tree, 28 best solution, best possible 26.791718 (50.85 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 37 rows 101 columns
# Cbc0010I After 4000 nodes, 224 on tree, 28 best solution, best possible 26.791718 (54.82 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 38 rows 102 columns
# Cbc0010I After 5000 nodes, 220 on tree, 28 best solution, best possible 26.791718 (57.03 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 35 rows 93 columns
# Cbc0010I After 6000 nodes, 204 on tree, 28 best solution, best possible 26.791718 (59.29 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 37 rows 98 columns
# Cbc0010I After 7000 nodes, 194 on tree, 28 best solution, best possible 26.791718 (61.60 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 37 rows 93 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 35 rows 90 columns
# Cbc0010I After 8000 nodes, 190 on tree, 28 best solution, best possible 26.791718 (63.67 seconds)
# Cbc0010I After 9000 nodes, 192 on tree, 28 best solution, best possible 26.791718 (65.87 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 34 rows 91 columns
# Cbc0038I Full problem 45 rows 240 columns, reduced to 34 rows 88 columns
# Cbc0010I After 10000 nodes, 194 on tree, 28 best solution, best possible 26.791718 (68.13 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 33 rows 91 columns
# Cbc0010I After 11000 nodes, 184 on tree, 28 best solution, best possible 26.791718 (70.05 seconds)
# Cbc0010I After 12000 nodes, 677 on tree, 28 best solution, best possible 26.812739 (95.44 seconds)
# Cbc0010I After 13000 nodes, 1168 on tree, 28 best solution, best possible 26.81791 (115.36 seconds)
# Cbc0010I After 14000 nodes, 1170 on tree, 28 best solution, best possible 26.81791 (117.10 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 42 rows 165 columns
# Cbc0010I After 15000 nodes, 1667 on tree, 28 best solution, best possible 26.820174 (138.38 seconds)
# Cbc0010I After 16000 nodes, 2165 on tree, 28 best solution, best possible 26.822176 (158.71 seconds)
# Cbc0010I After 17000 nodes, 2663 on tree, 28 best solution, best possible 26.823837 (177.26 seconds)
# Cbc0010I After 18000 nodes, 2667 on tree, 28 best solution, best possible 26.823837 (178.92 seconds)
# Cbc0010I After 19000 nodes, 3162 on tree, 28 best solution, best possible 26.825224 (198.07 seconds)
# Cbc0010I After 20000 nodes, 3658 on tree, 28 best solution, best possible 26.826087 (213.23 seconds)
# Cbc0010I After 21000 nodes, 4149 on tree, 28 best solution, best possible 26.826711 (229.58 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 38 rows 100 columns
# Cbc0010I After 22000 nodes, 4152 on tree, 28 best solution, best possible 26.826711 (231.90 seconds)
# Cbc0010I After 23000 nodes, 4648 on tree, 28 best solution, best possible 26.827338 (251.10 seconds)
# Cbc0010I After 24000 nodes, 5145 on tree, 28 best solution, best possible 26.828148 (268.99 seconds)
# Cbc0010I After 25000 nodes, 5639 on tree, 28 best solution, best possible 26.828816 (288.16 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 36 rows 100 columns
# Cbc0010I After 26000 nodes, 5636 on tree, 28 best solution, best possible 26.828816 (290.11 seconds)
# Cbc0010I After 27000 nodes, 6131 on tree, 28 best solution, best possible 26.82956 (308.14 seconds)
# Cbc0010I After 28000 nodes, 6627 on tree, 28 best solution, best possible 26.830238 (325.25 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 41 rows 140 columns
# Cbc0010I After 29000 nodes, 7125 on tree, 28 best solution, best possible 26.830824 (342.07 seconds)
# Cbc0010I After 30000 nodes, 7131 on tree, 28 best solution, best possible 26.830824 (343.69 seconds)
# Cbc0010I After 31000 nodes, 7629 on tree, 28 best solution, best possible 26.831376 (360.40 seconds)
# Cbc0010I After 32000 nodes, 8123 on tree, 28 best solution, best possible 26.831782 (377.10 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 42 rows 155 columns
# Cbc0010I After 33000 nodes, 8621 on tree, 28 best solution, best possible 26.832175 (392.89 seconds)
# Cbc0010I After 34000 nodes, 8625 on tree, 28 best solution, best possible 26.832175 (395.60 seconds)
# Cbc0010I After 35000 nodes, 9122 on tree, 28 best solution, best possible 26.832644 (413.49 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 43 rows 151 columns
# Cbc0010I After 36000 nodes, 9619 on tree, 28 best solution, best possible 26.833027 (431.10 seconds)
# Cbc0010I After 37000 nodes, 10116 on tree, 28 best solution, best possible 26.833375 (448.69 seconds)
# Cbc0010I After 38000 nodes, 10115 on tree, 28 best solution, best possible 26.833375 (450.39 seconds)
# Cbc0010I After 39000 nodes, 10289 on tree, 28 best solution, best possible 26.833375 (453.05 seconds)
# Cbc0010I After 40000 nodes, 10446 on tree, 28 best solution, best possible 26.833375 (454.62 seconds)
# Cbc0010I After 41000 nodes, 10506 on tree, 28 best solution, best possible 26.833375 (456.29 seconds)
# Cbc0010I After 42000 nodes, 10470 on tree, 28 best solution, best possible 26.833375 (461.71 seconds)
# Cbc0010I After 43000 nodes, 10586 on tree, 28 best solution, best possible 26.833375 (463.32 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 36 rows 95 columns
# Cbc0010I After 44000 nodes, 10650 on tree, 28 best solution, best possible 26.833375 (464.91 seconds)
# Cbc0010I After 45000 nodes, 10684 on tree, 28 best solution, best possible 26.833375 (466.38 seconds)
# Cbc0010I After 46000 nodes, 10630 on tree, 28 best solution, best possible 26.833376 (467.96 seconds)
# Cbc0010I After 47000 nodes, 10772 on tree, 28 best solution, best possible 26.833376 (469.92 seconds)
# Cbc0010I After 48000 nodes, 10884 on tree, 28 best solution, best possible 26.833376 (471.76 seconds)
# Cbc0010I After 49000 nodes, 10866 on tree, 28 best solution, best possible 26.833376 (473.41 seconds)
# Cbc0010I After 50000 nodes, 10797 on tree, 28 best solution, best possible 26.833376 (475.05 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 36 rows 96 columns
# Cbc0010I After 51000 nodes, 10931 on tree, 28 best solution, best possible 26.833376 (476.84 seconds)
# Cbc0010I After 52000 nodes, 10977 on tree, 28 best solution, best possible 26.833376 (478.47 seconds)
# Cbc0010I After 53000 nodes, 11006 on tree, 28 best solution, best possible 26.833376 (480.13 seconds)
# Cbc0010I After 54000 nodes, 10931 on tree, 28 best solution, best possible 26.833376 (482.04 seconds)
# Cbc0010I After 55000 nodes, 11040 on tree, 28 best solution, best possible 26.833376 (484.12 seconds)
# Cbc0010I After 56000 nodes, 11122 on tree, 28 best solution, best possible 26.833376 (485.74 seconds)
# Cbc0010I After 57000 nodes, 11159 on tree, 28 best solution, best possible 26.833376 (487.26 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 34 rows 90 columns
# Cbc0010I After 58000 nodes, 11105 on tree, 28 best solution, best possible 26.833376 (489.13 seconds)
# Cbc0010I After 59000 nodes, 11240 on tree, 28 best solution, best possible 26.833376 (490.73 seconds)
# Cbc0010I After 60000 nodes, 11331 on tree, 28 best solution, best possible 26.833376 (492.30 seconds)
# Cbc0010I After 61000 nodes, 11336 on tree, 28 best solution, best possible 26.833376 (494.14 seconds)
# Cbc0010I After 62000 nodes, 11281 on tree, 28 best solution, best possible 26.833377 (496.22 seconds)
# Cbc0010I After 63000 nodes, 11408 on tree, 28 best solution, best possible 26.833377 (497.91 seconds)
# Cbc0010I After 64000 nodes, 11561 on tree, 28 best solution, best possible 26.833377 (499.61 seconds)
# Cbc0038I Full problem 45 rows 240 columns, reduced to 37 rows 97 columns
# Cbc0010I After 65000 nodes, 11631 on tree, 28 best solution, best possible 26.833377 (501.34 seconds)
# Cbc0010I After 66000 nodes, 11548 on tree, 28 best solution, best possible 26.833377 (503.12 seconds)
# Cbc0010I After 67000 nodes, 11613 on tree, 28 best solution, best possible 26.833377 (504.77 seconds)
# Cbc0010I After 68000 nodes, 11755 on tree, 28 best solution, best possible 26.833377 (506.43 seconds)
# Cbc0010I After 69000 nodes, 11775 on tree, 28 best solution, best possible 26.833377 (508.40 seconds)
# Cbc0010I After 70000 nodes, 11706 on tree, 28 best solution, best possible 26.83338 (510.14 seconds)
# Cbc0010I After 71000 nodes, 11745 on tree, 28 best solution, best possible 26.83338 (511.70 seconds)
# Cbc0010I After 72000 nodes, 11826 on tree, 28 best solution, best possible 26.83338 (513.39 seconds)
# Cbc0010I After 73000 nodes, 11862 on tree, 28 best solution, best possible 26.83338 (514.86 seconds)
# Cbc0010I After 74000 nodes, 11786 on tree, 28 best solution, best possible 26.83338 (516.60 seconds)
# Cbc0010I After 75000 nodes, 11887 on tree, 28 best solution, best possible 26.83338 (518.21 seconds)
# Cbc0010I After 76000 nodes, 11962 on tree, 28 best solution, best possible 26.83338 (520.46 seconds)
# Cbc0010I After 77000 nodes, 11974 on tree, 28 best solution, best possible 26.83338 (521.97 seconds)
# Cbc0010I After 78000 nodes, 11902 on tree, 28 best solution, best possible 26.83338 (523.68 seconds)
# Cbc0010I After 79000 nodes, 11963 on tree, 28 best solution, best possible 26.83338 (525.18 seconds)
# Cbc0010I After 80000 nodes, 12004 on tree, 28 best solution, best possible 26.83338 (526.76 seconds)
# Cbc0010I After 81000 nodes, 12002 on tree, 28 best solution, best possible 26.83338 (528.36 seconds)
# Cbc0010I After 82000 nodes, 11961 on tree, 28 best solution, best possible 26.83338 (529.96 seconds)
# Cbc0010I After 83000 nodes, 12003 on tree, 28 best solution, best possible 26.83338 (532.19 seconds)
# Cbc0010I After 84000 nodes, 12105 on tree, 28 best solution, best possible 26.83338 (533.91 seconds)
# Cbc0010I After 85000 nodes, 12334 on tree, 28 best solution, best possible 26.83338 (535.64 seconds)
# Cbc0010I After 86000 nodes, 12321 on tree, 28 best solution, best possible 26.83338 (537.32 seconds)
# Cbc0010I After 87000 nodes, 12601 on tree, 28 best solution, best possible 26.83338 (539.11 seconds)
# Cbc0010I After 88000 nodes, 12804 on tree, 28 best solution, best possible 26.83338 (540.68 seconds)
# Cbc0010I After 89000 nodes, 12914 on tree, 28 best solution, best possible 26.83338 (542.36 seconds)
# Cbc0010I After 90000 nodes, 12874 on tree, 28 best solution, best possible 26.83338 (546.46 seconds)
# Cbc0010I After 91000 nodes, 13069 on tree, 28 best solution, best possible 26.83338 (548.17 seconds)
# Cbc0010I After 92000 nodes, 13224 on tree, 28 best solution, best possible 26.83338 (549.81 seconds)
# Cbc0010I After 93000 nodes, 13283 on tree, 28 best solution, best possible 26.83338 (551.31 seconds)
# Cbc0010I After 94000 nodes, 13217 on tree, 28 best solution, best possible 26.833382 (552.98 seconds)
# Cbc0010I After 95000 nodes, 13346 on tree, 28 best solution, best possible 26.833382 (554.57 seconds)
# Cbc0010I After 96000 nodes, 13483 on tree, 28 best solution, best possible 26.833382 (556.60 seconds)
# Cbc0010I After 97000 nodes, 13436 on tree, 28 best solution, best possible 26.833382 (558.42 seconds)
# Cbc0010I After 98000 nodes, 13379 on tree, 28 best solution, best possible 26.833382 (560.10 seconds)
# Cbc0010I After 99000 nodes, 13539 on tree, 28 best solution, best possible 26.833382 (561.73 seconds)
# Cbc0010I After 100000 nodes, 13631 on tree, 28 best solution, best possible 26.833382 (563.21 seconds)
# Cbc0010I After 101000 nodes, 13677 on tree, 28 best solution, best possible 26.833382 (564.73 seconds)
# Cbc0010I After 102000 nodes, 14175 on tree, 28 best solution, best possible 26.833762 (582.10 seconds)
# Cbc0010I After 103000 nodes, 14337 on tree, 28 best solution, best possible 26.833762 (583.76 seconds)
# Cbc0010I After 104000 nodes, 14415 on tree, 28 best solution, best possible 26.833762 (585.32 seconds)
# Cbc0010I After 105000 nodes, 14445 on tree, 28 best solution, best possible 26.833762 (586.91 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 28 (best possible 26.833762), took 8433753 iterations and 522273 nodes (601.63 seconds)
# Cbc0032I Strong branching done 45206 times (354976 iterations), fathomed 479 nodes and fixed 1306 variables
# Cbc0041I Maximum depth 107, 2283 variables fixed on reduced cost (complete fathoming 279 times, 416542 nodes taking 2516438 iterations)
# Cuts at root node changed objective from 26.1917 to 26.7917
# Probing was tried 59113 times and created 508784 cuts of which 118 were active after adding rounds of cuts (17.989 seconds)
# Gomory was tried 57374 times and created 817704 cuts of which 0 were active after adding rounds of cuts (51.904 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 100 times and created 142 cuts of which 0 were active after adding rounds of cuts (0.066 seconds)
# FlowCover was tried 100 times and created 193 cuts of which 0 were active after adding rounds of cuts (0.079 seconds)
# TwoMirCuts was tried 57374 times and created 754789 cuts of which 0 were active after adding rounds of cuts (12.092 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 671 times and created 206 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                28.00000000
# Lower bound:                    26.834
# Gap:                            0.04
# Enumerated nodes:               522273
# Total iterations:               8433753
# Time (CPU seconds):             601.67
# Time (Wallclock seconds):       613.17
#
# Total time (CPU seconds):       601.68   (Wallclock seconds):       613.18
# WARNING:pyomo.core:Loading a SolverResults object with an 'aborted' status, but containing a solution

# %%
print("\n--- Solution summary ---")
print("Objective (number of stocks used):", pyo.value(model.obj))

# Show which stocks are used and their cuts
used_stocks = [i for i in model.I if pyo.value(model.y[i]) >= 0.5]
print("Number of stocks used (y_i = 1):", len(used_stocks))
print("Used stock indices:", used_stocks)

for i in used_stocks:
        cuts = {j: int(round(pyo.value(model.x[i, j]))) for j in model.J if pyo.value(model.x[i, j]) > 1e-6}
        total_width = sum(item_lengths[j] * cuts[j] for j in cuts)
        print(f" Stock {i}: cuts {cuts}  total used width = {total_width} / {L}")

# Aggregate by item type (check demand fulfillment)
print("\nTotal pieces produced by type:")
for j in model.J:
    produced = sum(pyo.value(model.x[i, j]) for i in model.I)
    print(f" Item {j} (length {item_lengths[j]}): produced = {int(round(produced))}  demand = {demand[j]}")
# Out:
# --- Solution summary ---
# Objective (number of stocks used): 28.0
# Number of stocks used (y_i = 1): 28
# Used stock indices: [0, 1, 3, 4, 9, 10, 11, 12, 13, 14, 15, 16, 18, 19, 20, 21, 24, 25, 27, 28, 30, 31, 32, 33, 34, 35, 38, 39]
#  Stock 0: cuts {0: 1, 3: 4}  total used width = 119 / 120
#  Stock 1: cuts {2: 1, 3: 2}  total used width = 112 / 120
#  Stock 3: cuts {4: 2}  total used width = 96 / 120
#  Stock 4: cuts {1: 2, 4: 1}  total used width = 120 / 120
#  Stock 9: cuts {0: 1, 4: 2}  total used width = 115 / 120
#  Stock 10: cuts {1: 2, 4: 1}  total used width = 120 / 120
#  Stock 11: cuts {1: 2, 4: 1}  total used width = 120 / 120
#  Stock 12: cuts {0: 1, 1: 1, 2: 1}  total used width = 117 / 120
#  Stock 13: cuts {2: 1, 4: 1}  total used width = 110 / 120
#  Stock 14: cuts {2: 1, 4: 1}  total used width = 110 / 120
#  Stock 15: cuts {0: 1, 4: 2}  total used width = 115 / 120
#  Stock 16: cuts {2: 1, 3: 2}  total used width = 112 / 120
#  Stock 18: cuts {2: 1, 3: 2}  total used width = 112 / 120
#  Stock 19: cuts {0: 1, 3: 4}  total used width = 119 / 120
#  Stock 20: cuts {1: 1, 4: 1}  total used width = 84 / 120
#  Stock 21: cuts {0: 2, 3: 3}  total used width = 113 / 120
#  Stock 24: cuts {0: 1, 3: 4}  total used width = 119 / 120
#  Stock 25: cuts {0: 1, 1: 2, 3: 1}  total used width = 116 / 120
#  Stock 27: cuts {2: 1, 4: 1}  total used width = 110 / 120
#  Stock 28: cuts {0: 1, 1: 1, 2: 1}  total used width = 117 / 120
#  Stock 30: cuts {2: 1, 4: 1}  total used width = 110 / 120
#  Stock 31: cuts {2: 1, 4: 1}  total used width = 110 / 120
#  Stock 32: cuts {2: 1, 4: 1}  total used width = 110 / 120
#  Stock 33: cuts {2: 1, 3: 2}  total used width = 112 / 120
#  Stock 34: cuts {2: 1, 4: 1}  total used width = 110 / 120
#  Stock 35: cuts {2: 1, 3: 2}  total used width = 112 / 120
#  Stock 38: cuts {1: 1, 3: 3}  total used width = 111 / 120
#  Stock 39: cuts {2: 1, 3: 2}  total used width = 112 / 120
#
# Total pieces produced by type:
#  Item 0 (length 19): produced = 10  demand = 10
#  Item 1 (length 36): produced = 12  demand = 12
#  Item 2 (length 62): produced = 15  demand = 15
#  Item 3 (length 25): produced = 31  demand = 31
#  Item 4 (length 48): produced = 17  demand = 17
